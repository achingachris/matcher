# %% [markdown]
# # Introduction
#
# This notebook presents a generic LLM matchin algorithm which can be progressed as part of Swahilipot's matching of mentors and mentees, youth to opportunities etc. The algorithm has been developed to be as generic as possible, utilizing LLMs for identifying which fields
# to use in matching. It includes the following key components and being passed two dataframes:
#
# 1. An automatic analysis to determine fields to use for semantic search, locations and other types. This is controlled via an LLM prompt
# 2. A basic semantic search to get matches for each row in dataframe 1 in dataframe 2
# 3. For each match a distance is calculated using Google maps API to filter out matches which are too distant
# 4. For each remaining match, and LLM judge asseses the full record to filter out any which are not tru matches
#
# For step 1 an LLM is used, but once a `./data/matching_fields.json` is created it is used. This is also useful as it means you can manually adjust this file to include/exclude fields as-needed. This file is very important for the matching algorithm and can be a good place to tune to matching process.
#
# # Setup
#
# 1. Install [miniconda](https://docs.conda.io/en/latest/miniconda.html) by selecting the installer that fits your OS version. Once it is installed you may have to restart your terminal (closing your terminal and opening again)
# 2. In this directory, open terminal
# 3. `conda env create -f environment.yml`
# 4. `conda activate matching-env`
# 5. Open this notebook in VS Code and use this environment
#
# 6. You will need mentor and mentee data ...
#
# - (Mentees)[https://docs.google.com/spreadsheets/d/1i8ItmzyVEi5H0tII1C-zEWKjJJjHmeTkfPA9MDLPSLA/edit#gid=0] and the later (Mentees 2.0)(https://docs.google.com/spreadsheets/d/1U82YEHpcusuCC39mgGd0C_yAhYKf15W6MEab8kab3eU/edit#gid=0)
# - (Mentors)[https://docs.google.com/spreadsheets/d/1dEi1bsScI-gyFcLlGe-UajqzEzSb4q79ArWKrSHM4jw/edit#gid=0]
#
# These were provided by Chris from Swahilipot and have had PII removed. Download these into this folder and confirm there is no PII.
#
# 7. You will need to copy `.env` to `.env.example` and set keys for APIs

# %% [markdown]
# # Libraries and functions

# %%
# Imports
import os
import json
import sys
import pandas as pd
from time import sleep
import traceback

from langchain.docstore.document import Document
from langchain.text_splitter import CharacterTextSplitter
from langchain_community.document_loaders import TextLoader

from langchain.embeddings import AzureOpenAIEmbeddings
from langchain.chat_models import AzureChatOpenAI
from langchain.docstore.document import Document

from langchain.chat_models import AzureChatOpenAI
from langchain.schema import HumanMessage, SystemMessage
from langchain_community.vectorstores.pgvector import PGVector
from langchain_community.vectorstores.faiss import FAISS

from faiss import IndexFlatL2
from langchain_community.docstore.in_memory import InMemoryDocstore

import uuid
import googlemaps

from dotenv import load_dotenv

print('Cell Complete')
# Out:
# Cell Complete

# %%
# Loading data
load_dotenv('../.env')

MENTOR_DATA = './data/mentors.xlsx'
MENTEE_DATA = './data/mentee 2.0.xlsx'
DIST_MATRIX = './data/dist_matrix.json'
MATCHING_FIELDS_JSON = './data/matching_fields.json'
MATCHES_FILE = './data/matches.xlsx'

# For distance calculation
gmaps = googlemaps.Client(key=os.getenv('GOOGLE_MAPS_API_KEY'))
print('Data Loaded')
# Out:
# Data Loaded

# %%
def setup_models():
    '''
    Setup the models for the chat and embedding

    Returns:

    embedding_model: AzureOpenAIEmbeddings
    chat: AzureChatOpenAI

    '''
    embedding_model = AzureOpenAIEmbeddings(deployment=os.getenv("OPENAI_TEXT_COMPLETION_DEPLOYMENT_NAME"), 
                                            azure_endpoint=os.getenv("BASE_URL"), 
                                            chunk_size=16)

    chat = AzureChatOpenAI(model_name="gpt-35-turbo", 
                        azure_endpoint=os.getenv("BASE_URL"), 
                        temperature=1, max_tokens=1000)
    
    return embedding_model, chat

print(setup_models())
print('Models Setup')
# Out:
# (AzureOpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x1373d3410>, async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x137e95dd0>, model='text-embedding-ada-002', deployment='text-embedding-ada-002', openai_api_version='2023-07-01-preview', openai_api_base=None, openai_api_type='azure', openai_proxy='', embedding_ctx_length=8191, openai_api_key='6f4266921e2d481596516f157769c8c6', openai_organization=None, allowed_special=set(), disallowed_special='all', chunk_size=16, max_retries=2, request_timeout=None, headers=None, tiktoken_enabled=True, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False, default_headers=None, default_query=None, retry_min_seconds=4, retry_max_seconds=20, http_client=None, azure_endpoint='https://swahilipot-azure-openai.openai.azure.com/', azure_ad_token=None, azure_ad_token_provider=None, validate_base_url=True), AzureChatOpenAI(client=<openai.resources.chat.completions.Completions object at 0x137ea2890>, async_client=<openai.resources.chat.completions.AsyncCompletions object at 0x137eb7fd0>, model_name='gpt-35-turbo', temperature=1.0, openai_api_key='6f4266921e2d481596516f157769c8c6', openai_proxy='', max_tokens=1000, azure_endpoint='https://swahilipot-azure-openai.openai.azure.com/', openai_api_version='2023-07-01-preview', openai_api_type='azure'))
# Models Setup

# %%
# Stored in langchain_pg_collection and langchain_pg_embedding as this
def initialize_db(type, embedding_model):
    '''
    Initialize the database for storing the embeddings

    Args:
    type: str: Type of DB to use. Options are "PGVECTOR" or "FAISS"
    embedding_model: AzureOpenAIEmbeddings: The embedding model to use

    Returns:
    db: PGVector or FAISS: The initialized database
    
    '''


    db = {}

    COLLECTION_NAME = f"embedding"

    # Use Postgres DB if it has PGVector add-on
    if type == "PGVECTOR":
        CONNECTION_STRING = PGVector.connection_string_from_db_params(
            driver=os.environ.get("POSTGRES_DRIVER", "psycopg2"),
            host=os.environ.get("POSTGRES_HOST", "localhost"),
            port=int(os.environ.get("POSTGRES_PORT", "5432")),
            database=os.environ.get("POSTGRES_DB", "postgres"),
            user=os.environ.get("POSTGRES_USER", "postgres"),
            password=os.environ.get("POSTGRES_PASSWORD", "postgres"),
        )
        db = PGVector(
            collection_name=COLLECTION_NAME,
            connection_string=CONNECTION_STRING,
            embedding_function=embedding_model,
        )
    # Basic FAISS
    elif(type == "FAISS"):
        dimensions: int = len(embedding_model.embed_query("dummy"))
        db = FAISS(
            embedding_function=embedding_model,
            index=IndexFlatL2(dimensions),
            docstore=InMemoryDocstore(),
            index_to_docstore_id={},
            normalize_L2=False
        )
    else:
        print("Invalid DB type")
        sys.exit(1)

    return db

print('Completed')
# Out:
# Completed

# %%
def add_document(content, metadata, db):
    '''
    
    Add a document to the vecotr database along with its metadata

    Args:

    content: str: The content of the document
    metadata: dict: The metadata of the document
    db: PGVector or FAISS: The database to add the document to

    
    '''

    if metadata is None:
        metadata = {}

    uuid_str = str(uuid.uuid4())
    metadata['custom_id'] = uuid_str

    new_doc =  Document(
        page_content=content,
        metadata=metadata
    )
    id = db.add_documents(
        [new_doc],
        ids=[uuid_str]
    )

print('Completed')
# Out:
# Completed

# %%
def read_data(filename):
    '''
    
    Read data from an Excel file

    Args:

    filename: str: The name of the file to read

    Returns:

    data: pd.DataFrame: The data read from the file
    
    '''
    data = pd.read_excel(filename)
    data.columns = data.columns.str.strip()
    data.columns = data.columns.str.lower()
    data['id'] = data.index
    data['id'] = data['id'].apply(lambda x: f'{filename}-{x}')
    print(f"{filename} > {data.shape}")
    return data

print(read_data(MENTOR_DATA))
print('Completed')
# Out:
# ./data/mentors.xlsx > (47, 32)
#     first name  last name  gender  year of birth  \
# 0          NaN        NaN  Female           1998
# 1          NaN        NaN  Female           1999
# 2          NaN        NaN    Male           2000
# 3          NaN        NaN  Female           2000
# 4          NaN        NaN    Male           1998
# 5          NaN        NaN  Female           2001
# 6          NaN        NaN    Male           1998
# 7          NaN        NaN  Female           2000
# 8          NaN        NaN  Female           2002
# 9          NaN        NaN    Male           1994
# 10         NaN        NaN    Male           1989
# 11         NaN        NaN    Male           2002
# 12         NaN        NaN  Female           1987
# 13         NaN        NaN    Male           1989
# 14         NaN        NaN    Male           1998
# 15         NaN        NaN  Female           1993
# 16         NaN        NaN  Female           1997
# 17         NaN        NaN    Male           1998
# 18         NaN        NaN    Male           1999
# 19         NaN        NaN  Female           2000
# 20         NaN        NaN  Female           2000
# 21         NaN        NaN  Female           1994
# 22         NaN        NaN    Male           1996
# 23         NaN        NaN  Female           1998
# 24         NaN        NaN    Male           1999
# 25         NaN        NaN    Male           1995
# 26         NaN        NaN    Male           1982
# 27         NaN        NaN  Female           1999
# 28         NaN        NaN    Male           1991
# 29         NaN        NaN    Male           1989
# 30         NaN        NaN    Male           1989
# 31         NaN        NaN  Female           1996
# 32         NaN        NaN    Male           1997
# 33         NaN        NaN  Female           1992
# 34         NaN        NaN    Male           1995
# 35         NaN        NaN    Male           1992
# 36         NaN        NaN  Female           1994
# 37         NaN        NaN  Female           2000
# 38         NaN        NaN  Female           2000
# 39         NaN        NaN  Female           1998
# 40         NaN        NaN    Male           1995
# 41         NaN        NaN  Female           1996
# 42         NaN        NaN    Male           1999
# 43         NaN        NaN  Female           1996
# 44         NaN        NaN    Male           2000
# 45         NaN        NaN  Female           2000
# 46         NaN        NaN  Female           1997
#
#    are you a person with disability  email address  phone number  \
# 0                                No            NaN           NaN
# 1                                No            NaN           NaN
# 2                                No            NaN           NaN
# 3                                No            NaN           NaN
# 4                                No            NaN           NaN
# 5                                No            NaN           NaN
# 6                                No            NaN           NaN
# 7                                No            NaN           NaN
# 8                                No            NaN           NaN
# 9                                No            NaN           NaN
# 10                              Yes            NaN           NaN
# 11                               No            NaN           NaN
# 12                               No            NaN           NaN
# 13                               No            NaN           NaN
# 14                               No            NaN           NaN
# 15                               No            NaN           NaN
# 16                               No            NaN           NaN
# 17                               No            NaN           NaN
# 18                               No            NaN           NaN
# 19                               No            NaN           NaN
# 20                               No            NaN           NaN
# 21                               No            NaN           NaN
# 22                               No            NaN           NaN
# 23                               No            NaN           NaN
# 24                               No            NaN           NaN
# 25                               No            NaN           NaN
# 26                               No            NaN           NaN
# 27                               No            NaN           NaN
# 28                               No            NaN           NaN
# 29                               No            NaN           NaN
# 30                              Yes            NaN           NaN
# 31                               No            NaN           NaN
# 32                               No            NaN           NaN
# 33                               No            NaN           NaN
# 34                               No            NaN           NaN
# 35                               No            NaN           NaN
# 36                               No            NaN           NaN
# 37                               No            NaN           NaN
# 38                               No            NaN           NaN
# 39                               No            NaN           NaN
# 40                               No            NaN           NaN
# 41                               No            NaN           NaN
# 42                               No            NaN           NaN
# 43                               No            NaN           NaN
# 44                               No            NaN           NaN
# 45                               No            NaN           NaN
# 46                               No            NaN           NaN
#
#    what is your nationality? residence county residence sub-county  ...  \
# 0                     Kenyan          Mombasa                Nyali  ...
# 1                     Kenyan          Mombasa                Mvita  ...
# 2                     Kenyan          Mombasa                Mvita  ...
# 3                     Kenyan          Mombasa                Mvita  ...
# 4                     Kenyan            Kwale                  NaN  ...
# 5                     Kenyan          Mombasa                Mvita  ...
# 6                    Kenyan           Mombasa               Likoni  ...
# 7                     Kenyan          Mombasa               Likoni  ...
# 8                     Kenyan          Mombasa                Mvita  ...
# 9                     Kenyan          Mombasa               Likoni  ...
# 10                    Kenyan          Mombasa               Likoni  ...
# 11                    Kenyan          Mombasa                Mvita  ...
# 12                    Kenyan            Kwale                  NaN  ...
# 13                    Kenyan          Mombasa               Likoni  ...
# 14                    Kenyan          Mombasa                Mvita  ...
# 15                   Kenyan           Mombasa                Mvita  ...
# 16                    Kenyan          Mombasa                Mvita  ...
# 17                    Kenyan          Mombasa               Likoni  ...
# 18                    Kenyan          Mombasa                Mvita  ...
# 19                    Kenyan          Mombasa               Likoni  ...
# 20                    Kenyan          Mombasa               Likoni  ...
# 21                     KENYA          Mombasa               Likoni  ...
# 22                    Kenyan          Mombasa                Nyali  ...
# 23                   Kenyan           Mombasa              Kisauni  ...
# 24                    Kenyan          Mombasa              Kisauni  ...
# 25                   KENYAN           Mombasa            Changamwe  ...
# 26                    Kenyan          Mombasa                Nyali  ...
# 27                    Kenyan          Mombasa              Kisauni  ...
# 28                    KENYAN          Mombasa            Changamwe  ...
# 29                   Kenyan           Mombasa               Likoni  ...
# 30                    Kenyan          Mombasa               Likoni  ...
# 31                    Kenyan          Mombasa              Kisauni  ...
# 32                    Kenyan          Mombasa                Nyali  ...
# 33                    Kenyan          Mombasa                Nyali  ...
# 34                   KENYAN           Mombasa            Changamwe  ...
# 35                    Kenyan          Mombasa                Nyali  ...
# 36                   Kenyan           Mombasa              Kisauni  ...
# 37                    Kenyan          Mombasa            Changamwe  ...
# 38                   Kenyan           Mombasa              Kisauni  ...
# 39                    Kenyan          Mombasa              Kisauni  ...
# 40                    Kenyan          Mombasa                Jomvu  ...
# 41                   Kenyan           Mombasa              Kisauni  ...
# 42                    Kenyan          Mombasa                Nyali  ...
# 43                   KENYAN           Mombasa            Changamwe  ...
# 44                   Kenyan           Mombasa                Nyali  ...
# 45                   Kenyan           Mombasa                Mvita  ...
# 46                    Kenyan          Mombasa                Nyali  ...
#
#                          current job title  \
# 0                                Developer
# 1             Procurement and Admin Intern
# 2               Governance & Legal Officer
# 3                                      NaN
# 4                       M & E Focal Person
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                    Freelance Journalist.
# 9                          Teaching as U.T
# 10  case manager,community health promoter
# 11                            Case Manager
# 12                            Case Manager
# 13               Youth voice Volunteering
# 14                           Case Manager
# 15                                     NaN
# 16    Production assistant in a Tv station
# 17      Volunteer (counselor, facilitator)
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
# 24                                  Mentor
# 25                             PSIP intern
# 26                   Communication Officer
# 27                                     NaN
# 28                      Executive Director
# 29                            Youth voice
# 30                            case manager
# 31                            Case manager
# 32                                  Intern
# 33                                     NaN
# 34                           CASE MANAGER
# 35                                      CM
# 36                                 Mentor
# 37                         Project Officer
# 38                                     NaN
# 39                              Volunteer
# 40                                     NaN
# 41                            case manager
# 42                            Entrepreneur
# 43                               Volunteer
# 44                            Photographer
# 45                                     NaN
# 46                            Case Manager
#
#                                               company  \
# 0                                      Swahilipot Hub
# 1                                 Aga Khan Foundation
# 2                                          Msa County
# 3                                                 NaN
# 4                           Sambasports Youth Agenda
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                    Likoni Valentine  primary School
# 10                                                NaN
# 11                                     Swahilipothub
# 12                                     Swahilipot Hub
# 13                                             Shofco
# 14                                     Swahilipot Hub
# 15                                                NaN
# 16                                    AL - HUJJAH LTD
# 17              Likoni Community Development Program
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                     SwahiliPot Hub
# 25  Kenya Industrial Research & Development instit...
# 26                                      Kwacha Afrika
# 27                                                NaN
# 28             K.i.O.T.A COMMUNITY BASED ORGANISATION
# 29                                             Shofco
# 30                                     Swahilipot hub
# 31                                     Swahilipot hub
# 32                                                PSC
# 33                                                NaN
# 34                          SWAHILIPOTHUB FOUNDATION
# 35                                                SPH
# 36                                     Bomu hospital
# 37                      Stretchers Youth Organization
# 38                                                NaN
# 39                         Swahilipot Hub Foundation
# 40                                                NaN
# 41                           Swahilipothub Foundation
# 42                                                NaN
# 43                    GVRC; Nairobi Women's Hospital
# 44                         Swahilipot Hub Foundation
# 45                                                NaN
# 46                                    Swahillipot Hub
#
#                                your area of expertise  \
# 0                                         Technology
# 1                               Procurement and Admin
# 2                                               Legal
# 3              Website development , Community health
# 4                                     ICT & Software
# 5   Good in communicating, good leadership, self m...
# 6                                             Health
# 7                                          Designing
# 8            Communication and new media/online media
# 9   Training on Creative industries , Good custome...
# 10                                          fieldwork
# 11                                     Community work
# 12                                           Clerical
# 13                                      Communication
# 14              Project Management and Implementation
# 15      Social work and Sign language Interpretation
# 16                                          Presenter
# 17            Facilitation , guidance and counseling.
# 18  Creative industry i.e DeeJay, MCee, Dance also...
# 19  Art, designs, decorations, writing, fitness co...
# 20       Active listening and emotional intelligence
# 21                                   Enterprenuership
# 22                             Mentoring and Training
# 23                              Community engagement
# 24         Volunteer of community based organization
# 25       Administration and corporate communications
# 26  Communication for Development, Videography, Ed...
# 27                                        Technology
# 28  Mediator, specializing in mediation possess es...
# 29                                     Communication
# 30                                        social work
# 31                                        Mentorship
# 32                   Technologies in applied physics
# 33                        Soft skills and Hard skills
# 34  MENTORSHIP,COACHING ,BUSINESS TRAININGS AND BU...
# 35                        Finance and Data Analytics
# 36  Mentorship/SRHR/GBV/Entrepreneurship and finan...
# 37                                          Sociology
# 38                                       Procurement
# 39             Cybersecurity and Network Engineering
# 40                    Project Planning and Management
# 41            communications & live performing artist
# 42  Online freelancing, business management and co...
# 43                             Counseling Psychology
# 44                                     Phototography
# 45                             IT and Administration
# 46             Information Technology, Data Analytics
#
#                            what are your career goals  \
# 0   To be happy \nHave a diverse career  in techno...
# 1   1.Helping my organisation get the most out of ...
# 2   To grow in the legal field and expand my exper...
# 3    Nurturing aspiring developers, sharing insigh...
# 4   To be a Project lead in software designs for c...
# 5   Becoming a good mentor, starting a business, i...
# 6   Building good healthy informed network in the ...
# 7   Further my studies to become the best Engineer...
# 8   Intern at Swahili pot hub\nBuild networks\nSta...
# 9   Am seeing  myself a big Human Resources  in my...
# 10  take initiative and interest in all my work,tr...
# 11  I want to specialize in body works as an autom...
# 12  I Aspire to be among the decision makers in a ...
# 13  Became a leader I have abilities or enjoy guid...
# 14  Be a very competent, skilled and branded Proje...
# 15  Creating meaningful impact on individuals, fam...
# 16  Attaining stability and gaining more experienc...
# 17  To grow and become a competent social worker, ...
# 18  Embarking on a dynamic career in the creative ...
# 19  Be a creatives manager, manage artists and sel...
# 20  I aim at improving my Personal and professiona...
# 21  Complete my CPAS\nLook for money and do master...
# 22  Becoming a lead project coordinator in a proje...
# 23  Skill development goals, Acquiring new skills ...
# 24  1. Skill Development: Identifying specific tec...
# 25  Attain a master's degree as part of my career ...
# 26  My career goal as a Communication Officer is t...
# 27  Develop a business plan and financial projecti...
# 28  Skill Development: Pursuing opportunities to e...
# 29  Became a mentor.I want to help my mentees to d...
# 30  taking interest and initiative in all work tas...
# 31  By achieving my career goal, i want to focus o...
# 32  Become an expert in my field, experience caree...
# 33  Build networks\nPersonal development\nCareer s...
# 34  My goal is to be seen as a strong colleague wh...
# 35  Rise to the highest echelons within project ma...
# 36  Advance my education\nImprove my performance\n...
# 37  One of my career goals is to be the best propo...
# 38  1. Enhancing efficiency: Streamlining  process...
# 39  Advancing my existing career, Obtaining a prom...
# 40   I would like to work at a  senior management ...
# 41  Skill Development - Acquiring new technical sk...
# 42  In the coming years, my career boarders around...
# 43  Self knowledge-The first important goal of men...
# 44  Be the best version of myself in my field of w...
# 45  Education wise, I might as well proceed for my...
# 46  My career goal is to become an expert in Data ...
#
#                  what skills would you like to mentor  \
# 0                                         Technology
# 1   1.Leadership\n2.Sexual Reproductive Health\n3....
# 2   Leadership, personal development and goal sett...
# 3   Guidance \nFostering collaboration\nProblem so...
# 4   Art of volunteering\nEmbracing humanity and di...
# 5        Problem solving skill\nCommunication skill\n
# 6               Problem solving, respectful attitude
# 7   I want to mentor my mentees on setting their g...
# 8   Innovation, adaptability, photography, problem...
# 9                        More on Creative Industries
# 10                                   entrepreneurship
# 11  Creative arts since it is something that I als...
# 12  Soft skills like listening and communications ...
# 13                                        Leadership
# 14                      Self Discipline in all fields
# 15                                     Communication
# 16                               Editing\nPhotography
# 17  Communication skills\nLeadership \nTeam work\n...
# 18       Creative (Dj,MC & dance), Entrepreneurship,
# 19  Art and designs, journaling, social media mark...
# 20  Collaboration skills\nActive listening and com...
# 21  Expectations for roles,ethics and approppriet ...
# 22  General life knowledge, and major on financial...
# 23               Health\nEntrepreneurship\nLifeskills
# 24          How to look for employment opportunities
# 25  Career planning, mental health (stress managem...
# 26                Life Skills, and Videography skills
# 27  Language and communication,  creativity and pr...
# 28  Leadership Skills: Mentoring in leadership ski...
# 29                                         Leadership
# 30                                    enrepreneurship
# 31  Self-awareness \nTrust building \nRelationship...
# 32  Network and build relationships,help someone g...
# 33        Social work and counselling \nCareer choice
# 34                             Problem Solving Skills
# 35  Finance literacy, data analysis and digital sk...
# 36  A respectful attitude, problem solving, commun...
# 37  Communication Skills\nCareer Development Skill...
# 38                              Communication skills
# 39  Soft skills, Cybersecurity and Network Enginee...
# 40                                   Entrepreneurship
# 41  Leadership\nSelf-Awareness\nTime Management\nF...
# 42  Business Management\nCommunication\nOnline fre...
# 43  Positive attitude\nOpen to learning\nClear com...
# 44  Photography but I'm open to referring mentees ...
# 45                                 Computer literacy
# 46  Technical skills like Data Analytics, Soft ski...
#
#                         what are your financial goals  \
# 0                                  Financial freedom
# 1   Launching a business\nHaving a saving plan ( o...
# 2     To be stable enough to help as many as possible
# 3   Attaining financial stability through strategi...
# 4      To achieve at least six figure income a month
# 5                      Earning, saving and investing.
# 6   Reserving money for emergencies in future, res...
# 7                    Budgeting and expense management
# 8   One of my financial goals is to save up enough...
# 9   I want to create financial  Stable that can ma...
# 10        to buy shares in all big companies in kenya
# 11  Open another two savings account one for home ...
# 12  To be financially stable by 40 years old by es...
# 13                                 Starting investing
# 14                    To be a financially stable man.
# 15  Investing in further educate for professional ...
# 16  Saving Money\nManaging my bills. \nOpening dif...
# 17  Have a stable income through a business, this ...
# 18                                Become an investor
# 19                  Earn 300 dollars by end of months
# 20             Increase my earnings\nHave investments
# 21      Saving,earning,investing appropriate spending
# 22  Having a well structured and stable business t...
# 23  Financially stable\nPay bills on time\nBe able...
# 24  1. Salary Increase: Aim for a specific salary ...
# 25  To get a job that pays well like around 100,00...
# 26  Emergency Fund: To Save enough money to cover ...
# 27  Pay off my school loans\nSave money for regist...
# 28  Savings for Specific Goals: Saving money for s...
# 29                               Becoming a homeowner
# 30         buy shares in all large companies in Kenya
# 31              Saving money for my future necessity
# 32  Resolving student loan debt, became a home own...
# 33  Investment\nFinding a higher paying job\nEnjoy...
# 34                            To be financial stable.
# 35                            Financial independence
# 36  Own a house, saving for emergency, pay for my ...
# 37  To invest on income generating activities\nTo ...
# 38  1. Saving for emergencies: Building an emergen...
# 39  Investing for wealth accumulation, saving for ...
# 40  Making a total earnings of 150,000 Per month b...
# 41  Retirement Savings\nHomeownership\nEducation S...
# 42  Save for my higher studies.\nBecoming a home o...
# 43  Building an emergency fund\nStarting a busines...
# 44              To be able to be 'Financially Stable'
# 45  Be my own boss and to never have to ask anyone...
# 46  Achieve financial independence by accumulating...
#
#                       upload your resume if available  \
# 0   https://drive.google.com/open?id=1vAR8dmfeHSJp...
# 1                                                 NaN
# 2                                                 NaN
# 3   https://drive.google.com/open?id=1_m-XYOYTbUNi...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   https://drive.google.com/open?id=11aA8KDyaltPK...
# 9   https://drive.google.com/open?id=1CKjsENCwX8ho...
# 10                                                NaN
# 11                                                NaN
# 12  https://drive.google.com/open?id=12UEcNrr4oves...
# 13  https://drive.google.com/open?id=1Q8ghVxZIhHKG...
# 14  https://drive.google.com/open?id=1Bnw514oW7AZy...
# 15                                                NaN
# 16  https://drive.google.com/open?id=1tnuf3KSrjzSg...
# 17                                                NaN
# 18                                                NaN
# 19  https://drive.google.com/open?id=1REKEt1pODfjM...
# 20                                                NaN
# 21  https://drive.google.com/open?id=1l5M_D3AIdVtD...
# 22                                                NaN
# 23                                                NaN
# 24  https://drive.google.com/open?id=1JtnmjTJdiUJJ...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  https://drive.google.com/open?id=1pJyL7u67J6tT...
# 30  https://drive.google.com/open?id=1eIleaa63W65J...
# 31                                                NaN
# 32                                                NaN
# 33  https://drive.google.com/open?id=1tBf5V4_2IwiO...
# 34  https://drive.google.com/open?id=19Lz9CvNIPmsX...
# 35  https://drive.google.com/open?id=1gN91WM8iIc4z...
# 36                                                NaN
# 37                                                NaN
# 38  https://drive.google.com/open?id=1Yco4Qas2hYle...
# 39  https://drive.google.com/open?id=1qBiy7uZW1KiN...
# 40                                                NaN
# 41                                                NaN
# 42  https://drive.google.com/open?id=1E_40OV43ebnY...
# 43  https://drive.google.com/open?id=1p4QwgtWH2awj...
# 44  https://drive.google.com/open?id=1nt9X_1wKC6I_...
# 45  https://drive.google.com/open?id=1S7ENtBkIMv6W...
# 46  https://drive.google.com/open?id=1W8DT5rRuckGO...
#
#                                          linkedin url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   https://www.linkedin.com/in/nusra-juriah-b311b...
# 4   https://www.linkedin.com/in/tanaram?utm_source...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   https://www.linkedin.com/in/mitchell-ayieye-ab...
# 9   https://www.linkedin.com/in/swaleh-sadi-418044...
# 10  https://www.linkedin.com/in/mohamed-mlingo-913...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16  https://www.linkedin.com/in/haifa-mohamed-926a...
# 17                                                NaN
# 18  https://www.linkedin.com/in/kevin-kangogo-7779...
# 19                 www.linkedin.com/in/charlenemaraga
# 20                                                NaN
# 21                               www.linkedin.com/in/
# 22  https://www.linkedin.com/in/brian-bii-40035519...
# 23                                 Swabrina mohammed
# 24  https://www.linkedin.com/in/samuel-tei-1013802...
# 25                                    Omar Faissally
# 26                                                NaN
# 27  https://www.linkedin.com/in/mwanamisi-kassim-b...
# 28                                   Adam Shee Mwinyi
# 29                                                NaN
# 30  https://www.linkedin.com/in/mohamed-mlingo-913...
# 31                                                NaN
# 32                                                NaN
# 33                                  Catherine mwololo
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37          www.linkedin.com/in/mary-wasike-a922712a1
# 38                                                NaN
# 39  https://www.linkedin.com/in/rehema-said-35ab31...
# 40                                                NaN
# 41  https://www.linkedin.com/in/nancie-moraa-0429a...
# 42        www.linkedin.com/in/steven-mbungi-60b445291
# 43                                                NaN
# 44  https://www.linkedin.com/in/wafulakevin?utm_so...
# 45  https://www.linkedin.com/in/mariam-nassir-9842...
# 46  https://www.linkedin.com/in/marieta-muthoki-82...
#
#                              x (formerly twitter url)                      id
# 0                                                 NaN   ./data/mentors.xlsx-0
# 1                                                 NaN   ./data/mentors.xlsx-1
# 2                                                 NaN   ./data/mentors.xlsx-2
# 3   https://twitter.com/nusraabeid1?t=_GoQFluXWzww...   ./data/mentors.xlsx-3
# 4   https://x.com/ramadhankidm?t=Vc2NxiUZDWWGecDLA...   ./data/mentors.xlsx-4
# 5                                                 NaN   ./data/mentors.xlsx-5
# 6                                          @AilesBeka   ./data/mentors.xlsx-6
# 7                Https://twitter.com/Viju Vij97281741   ./data/mentors.xlsx-7
# 8                                                 NaN   ./data/mentors.xlsx-8
# 9   https://twitter.com/ZafoZanirani?t=SvM1QGD0_Rj...   ./data/mentors.xlsx-9
# 10                                                NaN  ./data/mentors.xlsx-10
# 11                                                NaN  ./data/mentors.xlsx-11
# 12                                                NaN  ./data/mentors.xlsx-12
# 13  Take a look at Abdull (@Abdull24324344): https...  ./data/mentors.xlsx-13
# 14                                                NaN  ./data/mentors.xlsx-14
# 15                                                NaN  ./data/mentors.xlsx-15
# 16                       https://x.com/haifaty_mohar/  ./data/mentors.xlsx-16
# 17                                                NaN  ./data/mentors.xlsx-17
# 18  https://x.com/djkams?t=U74nwmwMf14dibO7EVAffw&...  ./data/mentors.xlsx-18
# 19                                   Charlene Maraga   ./data/mentors.xlsx-19
# 20                                                NaN  ./data/mentors.xlsx-20
# 21                                               NONE  ./data/mentors.xlsx-21
# 22                                                NaN  ./data/mentors.xlsx-22
# 23                                        @swabzrina4  ./data/mentors.xlsx-23
# 24  https://x.com/SamuelTei66?t=SRPavHxbAA0fTIe0O-...  ./data/mentors.xlsx-24
# 25                                          @ofeisal4  ./data/mentors.xlsx-25
# 26                                                NaN  ./data/mentors.xlsx-26
# 27                                                NaN  ./data/mentors.xlsx-27
# 28                                   Adam Shee Mwinyi  ./data/mentors.xlsx-28
# 29  https://x.com/Abdull24324344?t=Gz5vJ5K8v3maVhU...  ./data/mentors.xlsx-29
# 30  https://x.com/mlingo_89?t=Vtt9-0XpuEKZxhFiUIn_...  ./data/mentors.xlsx-30
# 31                                                NaN  ./data/mentors.xlsx-31
# 32                                                NaN  ./data/mentors.xlsx-32
# 33                                  Catherine Mwikali  ./data/mentors.xlsx-33
# 34                                                NaN  ./data/mentors.xlsx-34
# 35                                                NaN  ./data/mentors.xlsx-35
# 36                                       Rukia Awuor   ./data/mentors.xlsx-36
# 37                    https://twitter.com/wasike86793  ./data/mentors.xlsx-37
# 38                                               Rael  ./data/mentors.xlsx-38
# 39                       https://twitter.com/Said0384  ./data/mentors.xlsx-39
# 40                                                NaN  ./data/mentors.xlsx-40
# 41  https://x.com/Moraa331423?t=esL3sWOAOeD64qKYYm...  ./data/mentors.xlsx-41
# 42                                                NaN  ./data/mentors.xlsx-42
# 43                                                NaN  ./data/mentors.xlsx-43
# 44  https://x.com/kevinwafula00?t=KjrbexoLJ8OBBSUn...  ./data/mentors.xlsx-44
# 45                                                NaN  ./data/mentors.xlsx-45
# 46                                                NaN  ./data/mentors.xlsx-46
#
# [47 rows x 32 columns]
# Completed

# %%
def call_llm(instructions, prompt, chat, retries=5, retry_count=0):
    '''
    
    Call the LLM model

    Args:

    instructions: str: Instructions to provide to the model
    prompt: str: The prompt to provide to the model
    chat: AzureChatOpenAI: The chat model to use
    retries: int: Number of retries to attempt
    retry_count: int: Current retry count

    Returns:

    response: dict: The response from the model

    '''
    messages = [
        SystemMessage(
            content=instructions
        ),
        HumanMessage(
            content=prompt
        ),
    ]
    try:
        response = chat(messages)
        response = json.loads(response.content)
        return response
    except Exception as e:
        print("Error calling LLM")
        print(chat(messages))
        retry_count += 1
        if retry_count < retries:
            sleep(1)
            response = call_llm(instructions, prompt, chat, retries=retries, retry_count=retry_count)
            return response
        else:
            print("Error calling LLM. Max retries reached")
            return None

print('Completed')
# Out:
# Completed

# %%
def matching_fields(data1, data2, chat, context_prompt, format_prompt="", force=False):
    '''
    
    Get the fields to use for matching. This generates a JSON record which drives how matching
    is done. It's controlled by prompts to determine fields types and output formats. Here are some examples ...

    fields_context_prompt = """
        You looking at two dataframes data1 and data2 to see which columns can be used for matching mentors to mentees
        Id fields like 'name', 'id' and 'email' CANNOT BE USED FOR MATCHING, exclude them in your response
        URL fields like 'url' cannot be used for matching
        Fields providing resume/CV locations cannot be used for matching
        Fields related to skills/interests and demographics can be used for matching
        Exclude fields related to strengths and weaknesses
        Exclude mentor fields related to goals
        IMPORTANT!!!! Exclude ward fields in location fields
        Always include area of interest fields
    """

    # Prompt used to decide output format when matching fields
    fields_format_prompt = """
    Please reply with a JSON record in this format:

        {
            "data1_fields": {
                "skills_fields": [<FIELD NAME>, ...],
                "location_fields": [<FIELD NAME>, ...],
                "demographics_fields": [<FIELD NAME>, ...],
                "preferred_mentorship_mode": [<FIELD NAME>, ...]
            },
            "data2_fields": {
                "skills_fields": [<FIELD NAME>, ...],
                "location_fields": [<FIELD NAME>, ...],
                "demographics_fields": [<FIELD NAME>, ...],
                "preferred_mentorship_mode": [<FIELD NAME>, ...]
            }
        }
    """

    Note: It creates a JSON file saved into ./data. If this file exists it will use it, otherwise it will regenerate. 
    The force parameter will force a regeneration.

    Args:

    data1: pd.DataFrame: The first dataset
    data2: pd.DataFrame: The second dataset
    chat: AzureChatOpenAI: The chat model to use
    context_prompt: str: The context prompt to use, controls how fields are classified and matched
    format_prompt: str: The format prompt for the output
    force: bool: Whether to force re-creation of the matching fields

    Returns:

    resp: dict: The response from the model
    
    '''

    if os.path.exists(MATCHING_FIELDS_JSON) and not force:
        print("Found existing fields matching file! Using it ...")
        with open(MATCHING_FIELDS_JSON) as f:
            resp = json.load(f)
        print(json.dumps(resp, indent=4))    
        return resp

    matches = []

    data1_cols = list(data1.columns)
    data2_cols = list(data2.columns)

    prompt = context_prompt
    prompt += f"Given these two records, what fields would be good for matching?"
    prompt += f"\n\nDATA1: {data1_cols}"
    prompt += f"\n\nDATA2: {data2_cols}"
    prompt += f"\n\nPlease reply with a JSON record in this format:"
    prompt += format_prompt
    
    resp = call_llm("", prompt, chat)
    print(json.dumps(resp, indent=4))    

    with open(MATCHING_FIELDS_JSON, 'w') as f:
        json.dump(resp, f, indent=4)

    return resp

print('completed')
# Out:
# completed

# %%
def subset_data(data, fields):
    '''
    
    Function to subset dataframe to a column list. Also drops empty columns.

    Args:

    data - Pandas dataframe
    fields - Columns to subset

    Returns:

    data - Pandas dataframe of subset data
    
    '''


    fields = list(set(fields) & set(data.columns))
    data = data[fields]
    # Drop any columns which are all null
    data = data.dropna(axis=1, how='all')
    return data

print('completed')
# Out:
# completed

# %%
def index_data(data_content, data_all, db):
    '''

    Adds documents to the vector databse, with their embeddings. 

    Args:

    data_content: Pandas dataframe, data to be indexed, usually a subset of columns
    data_all: Pandas data frame of the data but with all columns, used to store metadata for each embedding
    db: Vecotr DB, see initialize_db above
    '''
    for index, row in data_all.iterrows():
        rec = data_content.iloc[index].to_dict()
        content = ""
        # Remove keys
        for r in rec:
            content += f"{rec[r]};"
        content = content.replace('\n', ';')
        metadata = row.to_dict()
        add_document(content, metadata, db)
        
        
def get_distance(addr1, addr2):
    key = f"{addr1}__{addr2}"
    with open(DIST_MATRIX) as f:
        dist_matrix = json.load(f)
    if key in dist_matrix:
        return dist_matrix[key]
    else:
        return -9999999

def calc_dist_matrix(addresses1, addresses2, skip_strings):
    '''
    For two lists of unique addresses or location strings, calculates their distance to build
    a dictionary of address combinations and their distances, stored to file.

    Args:

    addresses1 - List of from addresses/location fields
    addresses2 - List of to addresses/location fields
    skip_strings - List of strings which force records to be skipped

    Returns:

    dist_matrix: Dictionary with key <addresses1>__<addresses2> and vlues of distance in km

    Dictionary also stored in ./data.
    '''
    dist_matrix = {}
    for addr1 in list(set(addresses1)):
        for addr2 in list(set(addresses2)):
            skip = False
            if addr1 == '' or addr2 == '':
                skip = True
            for s in skip_strings:
                if s in addr1 or s in addr2:
                    skip = True
                    break
            if skip:
                continue
            key = f"{addr1}__{addr2}"
            print(key)
            if key not in dist_matrix:
                if addr1 == addr2 or 'Mombasa Metropolitan' in addr2:
                    dist_matrix[key]  = 0.0
                else:
                    dist = gmaps.distance_matrix(addr1,addr2, units='metric')['rows'][0]['elements'][0]
                    if dist['status'] == 'OK':
                        dist_matrix[key] = dist['distance']['value']/1000.
                        print(f"        Distance between {addr1} and {addr2} is {dist_matrix[key]} km")
                    else:
                        dist_matrix[key] = None

    with open('dist_matrix.json', 'w') as f:
        json.dump(dist_matrix, f, indent=4) 

    return dist_matrix

def set_addresses(data, fields):
    '''
    
    Sets an 'address' field on a dataframe, by concatenating vlaues in address 'fields'

    Args:

    data - Pandas dataframe
    fields - List of address-related fields

    Returns:

    data - Parndas dataframe with extra column 'address'
    
    '''
    data_add = data[fields]
    addresses = data_add.apply(lambda x: ','.join(x.dropna().astype(str)), axis=1)
    addresses = addresses.str.lower()
    data['address'] = addresses
    return data


print('Completed')
# Out:
# Completed

# %%
def get_ai_check_fields(match_fields):
    '''
    
    Using the fields match JSON record, gets a list of all fields that might be useful for the AI
    match checker.

    Args:

    match_fields - dictionary of mathing fields, as output by function `match_fields`
    
    Returns:

    ai_check_fields - list of field names
    '''

    ai_check_fields = []
    for k in match_fields:
        ai_check_fields += match_fields[k]
    print(ai_check_fields)
    return ai_check_fields

def check_pii(data, chat):
    '''
    
    Check if data contains PII columns. Note, this is not perfect and should be used as a guide only.

    Args:

    data: pd.DataFrame: The data to check for PII
    prompt: str: The prompt to use to check for PII
    chat: AzureChatOpenAI: The chat model to use

    Returns:

    matching_fields_list: dict: The matching fields list
    
    '''

    pii_prompt = """

    =================

    Analyze the text above 
    Please identify whether not the above text contains any instances where a person's name is given 
    Please identify all email addresses 
    I need to find any exact dates that correspond to the day a person was born. They typically follow the format MM/DD/YYYY or DD/YY or other combinations.  They Must have a day number. Can you find them in the text? 
    Find any locations that could be a person's home address in this text. They must have a stret number or apartment number.

    Your response should be a JSON record in this format:

    {
        "has_pii": <"yes" or "no">,
        "fields": "<FIELD>, ..."
        "values": "<VALUE>, ..."
    }

    """

    data = data.sample(5)
    data = data.to_dict(orient='records')
    data = json.dumps(data, indent=4)

    # Noting here we need a more powerful model to be safe
    chat = AzureChatOpenAI(azure_deployment="gpt-4-turbo", 
                    azure_endpoint=os.getenv("BASE_URL"), 
                    temperature=0, max_tokens=1000)

    # Check data1 for PII
    print("\n\nChecking data for PII ...")
    prompt = data  + pii_prompt 
    print(prompt)

    resp = call_llm("", prompt, chat)

    if resp['has_pii'] == 'yes':
        print("PII detected!")
        print(f"Fields: {resp['fields']}")
        print(f"Values: {resp['values']}")
        sys.exit()
    else:
        print("No PII detected")

def ai_check(data1, data2, chat, context_prompt=""):
    '''
    
    Checks a match as found by semantic search to see it it's still a match when considering more fields

    Args:

    data1 - JSON record of record1, being a subset of input table row by ai_match_fields
    data2 - JSON record of record2, being a subset of input table row by ai_match_fields
    context_prompt String, prompt to guide the AI matcher further

    Returns:

    rep - dict, stating answer and reason
    '''

    prompt = context_prompt
    prompt += f"Given these two records, what fields would be good for matching?"
    prompt += f"\n\nDATA1: {data1}"
    prompt += f"\n\nDATA2: {data2}"
    prompt += f"\n\nPlease reply with a JSON record in this format:"
    prompt += """
        {
            "answer": <"yes" or "no">,
            "reason": <"reason for answer">    
        }
    """
    resp = call_llm("", prompt, chat)
    print(json.dumps(resp, indent=4))    
    return resp

print('Completed')
# Out:
# Completed

# %%
def run_matching_batch(data1, data2, rec1_name, rec2_name, fields_context_prompt, fields_format_prompt, ai_check_prompt, \
                       max_travel_distance_km=15, data2_cap=10, force=False):
    
    '''
    Main batch function for calculating matching between two dataframes using a staged approach (i) Simple vector similarity
    top k matches, then reviewed for distances between data, then finally assessed by AI match checker.
    
    Args:

    data1 - Pandas dataframe of first dataset (eg mentors)
    data2 - Pandas dataframe of second dataset to match against (eg mentees)
    rec1_name - String name of first dataset, eg 'mentors'
    rec2_name - String name of second dataset, eg 'menteess'
    fields_context_prompt: str: The context prompt to use, controls how fields are classified and matched, see 'matching_fields' function
    fields_format_prompt: str: The format prompt for the output, see 'matching_fields' function
    ai_check_prompt: str, prompt to guide the AI matcher further, see ai_check function
    max_traveL_distance_km: Maximum travel distance allowed for a match. If exceeded, match field <rec1_name>_distance_match is set to 'no'
    data2_cap: Number of data2 records to try and match with all of data1
    force: Bool, used to force refresh of matching_fields JSON record

    Returns:

    matches: Pandas dataframe of each match with all data1 fields plus extra columns for the matched data2 fields

    Note, the matches willl have a row per match, so mentees values are repeated for each mentor. The function also saves
    matches to an excel file in ./data 

    '''

    print("\n=====> Setting up models ...")
    embedding_model, chat = setup_models()
    db = initialize_db('FAISS', embedding_model)

    print("\n=====> Identifying match fields ...")
    matching_fields_list = matching_fields(data1, data2, chat, fields_context_prompt, fields_format_prompt, force=force)

    # Please do not comment this out. :) 
    print("\n=====> Checking for PII  ...")
    check_pii(data1,chat)
    check_pii(data2,chat)

    print("\n=====> Calculating travel distance matrix ...")
    data1 = set_addresses(data1, matching_fields_list['data1_fields']['location_fields'])
    data2 = set_addresses(data2, matching_fields_list['data2_fields']['location_fields'])
    dist_matrix = calc_dist_matrix(data1['address'].unique(), data2['address'].unique(), skip_strings=['outside mombasa'])

    print("\n=====> Calculating index for semantic match ...")
    data1_search = subset_data(data1, matching_fields_list['data1_fields']['skills_fields'])
    data2_search = subset_data(data2, matching_fields_list['data2_fields']['skills_fields'])
    print(list(data1_search.columns))
    data1_index = index_data(data1_search, data1, db)

    print("\n=====> Extracting AI check fields for datasets ...")
    ai_check_fields1 = get_ai_check_fields(matching_fields_list['data1_fields'])
    ai_check_fields2 = get_ai_check_fields(matching_fields_list['data2_fields'])

    print("\n=====> Starting batch matching of mentees ...")
    matches = []
    for index, row in data2[0:data2_cap].iterrows():
        
        try:

            # Simple semantic search
            data2_search_fields = list(data2_search.iloc[index]) 
            data2_search_string = " ".join(data2_search_fields)
            print(f"\n\n{rec2_name}: {data2_search_string}")
            print(f"{rec2_name} ID: {row['id']}")
            print(f"{rec2_name} Address: {row['address']}")
            docs_and_scores = db.similarity_search_with_score(data2_search_string, top_k=3)
            print(f"RESULTS: {len(docs_and_scores)}")

            data2_address = row['address']
            data2_ai_record = data2.iloc[index][ai_check_fields2].to_dict()
            data2_ai_record = json.dumps(data2_ai_record,indent=4)
            print(f"{rec2_name} AI Fields:\n")
            print(data2_ai_record)

            # Filter simple results by secondary filters (distance and ai check)
            data2['matches'] = ""
            for d in docs_and_scores:

                data1_skills = d[0].page_content
                data1_full = d[0].metadata

                # Flag if distances are too far
                data1_address = data1_full['address']
                travel_distance_km = get_distance(data1_address, data2_address)
                distance_match = 'yes'
                if travel_distance_km > max_travel_distance_km:
                    print("Match found but distance too far")
                    distance_match = 'no'

                print(f"Score: {d[1]}")
                print(f"{rec1_name} ID: {data1_full['id']}")
                print(f"{rec1_name} match terms: {data1_skills}")
                print(f"{rec1_name} location: {data1_full['address']}")
                print(f"Distance to {rec1_name}: {travel_distance_km} km")

                data1_ai_record = pd.DataFrame([data1_full])
                data1_ai_record = data1_ai_record[ai_check_fields1]
                data1_ai_record = json.loads(data1_ai_record.to_json(orient="records"))[0]
                data1_ai_record = json.dumps(data1_ai_record,indent=4)
                print("AI Check fields:")
                print(f"   {rec2_name} : {data2_ai_record}")
                print(f"   {rec1_name}: {data1_ai_record}")
                print("******* AI CHECK:")
                ai_check_result = ai_check(data1_ai_record, data2_ai_record, chat, ai_check_prompt)

                # Build match record
                r = {}
                r['id'] = row['id']
                r['address'] = data2_address
                r[f'{rec1_name}_id'] = data1_full['id']
                for f in json.loads(data1_ai_record):
                    r[f'{rec1_name}_{f}'] = data1_full[f]
                r[f'{rec1_name}_address'] = data1_address
                r[f'{rec1_name}_score'] = d[1]
                r[f'{rec1_name}_match_terms'] = data1_skills
                r[f'{rec1_name}_distance'] = travel_distance_km
                r[f'{rec1_name}_json_comparison'] = f"MENTEE:\n{data2_ai_record}\n\nMENTOR:\n{data1_ai_record}"
                r[f'{rec1_name}_distance_match'] = distance_match
                r[f'{rec1_name}_ai_check_result'] = ai_check_result['answer']
                r[f'{rec1_name}_ai_check_reason'] = ai_check_result['reason']
                matches.append(r)

        except Exception as e:
            print(f"Error processing record {index}")
            print(traceback.format_exc())
            print(e)


    if len(matches) > 0:
        matches = pd.DataFrame(matches)
        data2 = data2.merge(matches, on='id', how='left')
        print(f"Saving matches to {MATCHES_FILE}")
        data2.to_excel(MATCHES_FILE, index=False)

    return data2

print('complete')
# Out:
# complete

# %% [markdown]
# ## Matching batch for mentors and mentees

# %%
print("Reading in two dataframes to match ...")
mentors = read_data(MENTOR_DATA)
print(mentors.columns)
mentees = read_data(MENTEE_DATA)
print(mentees.columns)
# Out:
# Reading in two dataframes to match ...
# ./data/mentors.xlsx > (47, 32)
# Index(['first name', 'last name', 'gender', 'year of birth',
#        'are you a person with disability', 'email address', 'phone number',
#        'what is your nationality?', 'residence county', 'residence sub-county',
#        'residence ward', 'please list you core values',
#        'your free time activities',
#        'what are some of the personal challenges you go through',
#        'what are your strengths', 'what are your weaknesses',
#        'preferred mode of mentorship', 'your religion', 'cultural influences',
#        'mentee demographics preference', 'latest educational qualification',
#        'certifications', 'current job title', 'company',
#        'your area of expertise', 'what are your career goals',
#        'what skills would you like to mentor', 'what are your financial goals',
#        'upload your resume if available', 'linkedin url',
#        'x (formerly twitter url)', 'id'],
#       dtype='object')
# ./data/mentee 2.0.xlsx > (1634, 25)
# Index(['first name', 'last name', 'phone number', 'email', 'year of birth',
#        'gender', 'are you a person with disability?', 'county of residence',
#        'sub county of residence (sub counties in mombasa)',
#        'ward of residence', 'highest level of education completed',
#        'are you employed', 'are you running a business',
#        'whats your area of interest?',
#        'if you selected other, please elaborate (if not, respond with n/a)',
#        'mode of mentorship ( remote / physical / any)',
#        'prefered mentor gender (male / female / any)',
#        'what are your strengths', 'what are your weaknesses',
#        'what are your career goals',
#        'what skills would you like to be mentored',
#        'what are your financial goals', 'upload your resume if available',
#        'who referred you? (your case manager/mentor)', 'id'],
#       dtype='object')

# %%
# Prompt used when automatically identifying matching fields
fields_context_prompt = """
    You looking at two dataframes data1 and data2 to see which columns can be used for matching mentors to mentees
    Id fields like 'name', 'id' and 'email' CANNOT BE USED FOR MATCHING, exclude them in your response
    URL fields like 'url' cannot be used for matching
    Fields providing resume/CV locations cannot be used for matching
    Fields related to skills/interests and demographics can be used for matching
    Exclude fields related to strengths and weaknesses
    Exclude mentor fields related to goals
    IMPORTANT!!!! Exclude ward fields in location fields
    Always include area of interest fields
"""

# Prompt used to decide output format when matching fields
fields_format_prompt = """
Please reply with a JSON record in this format:

        {
            "data1_fields": {
                "skills_fields": [<FIELD NAME>, ...],
                "location_fields": [<FIELD NAME>, ...],
                "demographics_fields": [<FIELD NAME>, ...],
                "preferred_mentorship_mode": [<FIELD NAME>, ...]
            },
            "data2_fields": {
                "skills_fields": [<FIELD NAME>, ...],
                "location_fields": [<FIELD NAME>, ...],
                "demographics_fields": [<FIELD NAME>, ...],
                "preferred_mentorship_mode": [<FIELD NAME>, ...]
            }
        }
"""

ai_check_prompt = """
    You are an AI checking potential matches between mentors and mentees
    You ignore locations and focus on other fields
    If mentor or mentee wants similar demographics, such as gender, age etc, be very careful comparing those fields
    Given the above, is this mentor matched to this mentee?
"""

max_travel_distance_km = 15
mentee_cap = 500

print('completed')
# Out:
# completed

# %%
matches = run_matching_batch(mentors, mentees, 'mentor', 'mentee', fields_context_prompt, fields_format_prompt, ai_check_prompt, \
                   max_travel_distance_km, mentee_cap)
# Out:
# =====> Setting up models ...
#
# =====> Identifying match fields ...
# Found existing fields matching file! Using it ...
# {
#     "data1_fields": {
#         "skills_fields": [
#             "what skills would you like to mentor"
#         ],
#         "location_fields": [
#             "residence county",
#             "residence sub-county"
#         ],
#         "demographics_fields": [
#             "gender",
#             "year of birth"
#         ],
#         "preferred_mentorship_mode": [
#             "preferred mode of mentorship"
#         ]
#     },
#     "data2_fields": {
#         "skills_fields": [
#             "whats your area of interest?"
#         ],
#         "location_fields": [
#             "county of residence",
#             "sub county of residence (sub counties in mombasa)"
#         ],
#         "demographics_fields": [
#             "gender",
#             "year of birth"
#         ],
#         "preferred_mentorship_mode": [
#             "mode of mentorship ( remote / physical / any)"
#         ]
#     }
# }
#
# =====> Checking for PII  ...
#
#
# Checking data for PII ...
# [
#     {
#         "first name": NaN,
#         "last name": NaN,
#         "gender": "Female",
#         "year of birth": 1992,
#         "are you a person with disability": "No",
#         "email address": NaN,
#         "phone number": NaN,
#         "what is your nationality?": "Kenyan",
#         "residence county": "Mombasa",
#         "residence sub-county": "Nyali",
#         "residence ward": "Bamburi",
#         "please list you core values": "Integrity\ncompassion\nTeamwork\nRespect\nCompetency\nHonesty",
#         "your free time activities": "Reading\nFun activities eg. swimming\nmentor young people",
#         "what are some of the personal challenges you go through": "Overcome fear\nGet a new job/career development\nFinances\n",
#         "what are your strengths": "Flexible\nEmpathetic\nTeam player\nTime management\nPassionate\nPatient",
#         "what are your weaknesses": "Saying No\nPerfectionist\nProctastination\nEmotional",
#         "preferred mode of mentorship": "Physical",
#         "your religion": "Christian",
#         "cultural influences": "Language, traditions, norms, ethinicity ",
#         "mentee demographics preference": "Same as mine",
#         "latest educational qualification": "University",
#         "certifications": "Degree",
#         "current job title": NaN,
#         "company": NaN,
#         "your area of expertise": "Soft skills and Hard skills",
#         "what are your career goals": "Build networks\nPersonal development\nCareer stability\nLearn a new skill\nGet a job in my dream organization\nGet a new certificate\nstart a bussiness\nAdvance in leadership positions\nMentor young snd upcoming proffessionals\nEstablish a charitable organization",
#         "what skills would you like to mentor": "Social work and counselling \nCareer choice",
#         "what are your financial goals": "Investment\nFinding a higher paying job\nEnjoy financial freedom\nSave for retirement",
#         "upload your resume if available": "https://drive.google.com/open?id=1tBf5V4_2IwiOXtviotrUfr9EU4wnAYCZ",
#         "linkedin url": "Catherine mwololo",
#         "x (formerly twitter url)": "Catherine Mwikali",
#         "id": "./data/mentors.xlsx-33"
#     },
#     {
#         "first name": NaN,
#         "last name": NaN,
#         "gender": "Female",
#         "year of birth": 1994,
#         "are you a person with disability": "No",
#         "email address": NaN,
#         "phone number": NaN,
#         "what is your nationality?": "Kenyan ",
#         "residence county": "Mombasa",
#         "residence sub-county": "Kisauni",
#         "residence ward": "Bamburi ",
#         "please list you core values": "Discipline\nIntegrity\nRespect\nResponsibility and compassion ",
#         "your free time activities": "I read a book known as atomic habits or watch a movie ",
#         "what are some of the personal challenges you go through": "Life changes, loneliness ",
#         "what are your strengths": "Honesty",
#         "what are your weaknesses": "Limited experience in a non-essential task ",
#         "preferred mode of mentorship": "Hybrid",
#         "your religion": "Muslim",
#         "cultural influences": "None ",
#         "mentee demographics preference": "Any",
#         "latest educational qualification": "University",
#         "certifications": "Certificate",
#         "current job title": "Mentor ",
#         "company": "Bomu hospital ",
#         "your area of expertise": "Mentorship/SRHR/GBV/Entrepreneurship and financial capability /management ",
#         "what are your career goals": "Advance my education\nImprove my performance\nBuild up my next work\ninteract more with people who we are in the same field so as I can gain more and more experience a'and knowledge get to learn new skills things each day... Be a good team leader attend more and more seminars ",
#         "what skills would you like to mentor": "A respectful attitude, problem solving, communication ",
#         "what are your financial goals": "Own a house, saving for emergency, pay for my education and enjoy my financial freedom ",
#         "upload your resume if available": NaN,
#         "linkedin url": NaN,
#         "x (formerly twitter url)": "Rukia Awuor ",
#         "id": "./data/mentors.xlsx-36"
#     },
#     {
#         "first name": NaN,
#         "last name": NaN,
#         "gender": "Female",
#         "year of birth": 2000,
#         "are you a person with disability": "No",
#         "email address": NaN,
#         "phone number": NaN,
#         "what is your nationality?": "Kenyan",
#         "residence county": "Mombasa",
#         "residence sub-county": "Likoni",
#         "residence ward": "Shika Adabu",
#         "please list you core values": "Disciplined\nRespect and humility \nResponsible\nFairness",
#         "your free time activities": "Internet surfing",
#         "what are some of the personal challenges you go through": "Loneliness,fear,relations",
#         "what are your strengths": "Am focused and disciplined",
#         "what are your weaknesses": "Publicity ",
#         "preferred mode of mentorship": "Physical",
#         "your religion": "Muslim",
#         "cultural influences": "Behaviour and attitudes",
#         "mentee demographics preference": "Close to me",
#         "latest educational qualification": "University",
#         "certifications": "Diploma",
#         "current job title": NaN,
#         "company": NaN,
#         "your area of expertise": "Active listening and emotional intelligence ",
#         "what are your career goals": "I aim at improving my Personal and professional growth\nImprove communication skills\nGrow my business and gain more marketing skills\nI would love to be a leader and help youths  and women in my space to sustainable development.",
#         "what skills would you like to mentor": "Collaboration skills\nActive listening and communication\nEmpathetic and self motivation \nLeadership skills",
#         "what are your financial goals": "Increase my earnings\nHave investments",
#         "upload your resume if available": NaN,
#         "linkedin url": NaN,
#         "x (formerly twitter url)": NaN,
#         "id": "./data/mentors.xlsx-20"
#     },
#     {
#         "first name": NaN,
#         "last name": NaN,
#         "gender": "Male",
#         "year of birth": 1994,
#         "are you a person with disability": "No",
#         "email address": NaN,
#         "phone number": NaN,
#         "what is your nationality?": "Kenyan",
#         "residence county": "Mombasa",
#         "residence sub-county": "Likoni",
#         "residence ward": "Shikaadabu ",
#         "please list you core values": "My core Value is to ensure Youth are empowered to sustain  their Living by giving the  knowledge  and Business empowerment.",
#         "your free time activities": "Drama, poem, acting, Scrip writing, Training  corolverse",
#         "what are some of the personal challenges you go through": "I'm struggling  to help more youth despite  myselve having problems.",
#         "what are your strengths": "Determination, once I determine  I have to fulfill  it.",
#         "what are your weaknesses": "My kindness is my weakness",
#         "preferred mode of mentorship": "Physical",
#         "your religion": "Muslim",
#         "cultural influences": "Am influenced by Digo  and Giriam tradition  dances",
#         "mentee demographics preference": "Any",
#         "latest educational qualification": "Some college",
#         "certifications": "Diploma",
#         "current job title": "Teaching as U.T",
#         "company": "Likoni Valentine  primary School",
#         "your area of expertise": "Training on Creative industries , Good customer service, Computers, Aviation service and Human Resource.",
#         "what are your career goals": "Am seeing  myself a big Human Resources  in my own ORGANIZATION  that will Support Youth. First I want to go back to college  to complete my diploma  on Human Resources  with Knec Certification, I have online diploma of Human Resources  from ALISON LEARNING.  Am fight for KENYAN Recognization Diploma. Then I shall start a diploma  in Business management. Through  Swahili pot I will got opportunities to join job or Organization  that will enhance me to achieve  my goal by being  employed. ",
#         "what skills would you like to mentor": "More on Creative Industries ",
#         "what are your financial goals": "I want to create financial  Stable that can manage my expenditures  and my Family.",
#         "upload your resume if available": "https://drive.google.com/open?id=1CKjsENCwX8homkDbZM-wTOeG2IfKZ6x-",
#         "linkedin url": "https://www.linkedin.com/in/swaleh-sadi-418044231?utm_source=share&utm_campaign=share_via&utm_content=profile&utm_medium=android_app",
#         "x (formerly twitter url)": "https://twitter.com/ZafoZanirani?t=SvM1QGD0_RjfYCrUSSnPcQ&s=09",
#         "id": "./data/mentors.xlsx-9"
#     },
#     {
#         "first name": NaN,
#         "last name": NaN,
#         "gender": "Female",
#         "year of birth": 1996,
#         "are you a person with disability": "No",
#         "email address": NaN,
#         "phone number": NaN,
#         "what is your nationality?": "KENYAN ",
#         "residence county": "Mombasa",
#         "residence sub-county": "Changamwe",
#         "residence ward": "Kipevu ",
#         "please list you core values": "Confidentiality\nCompassion - by being empathetic and non- judgemental\nCollaboration \nRespect for Autonomy",
#         "your free time activities": "Reading ",
#         "what are some of the personal challenges you go through": "Burn out \nClient resistance/ Lack of engagement ",
#         "what are your strengths": "Genuine interest of Others\nAbility to active listen",
#         "what are your weaknesses": "Finding work-life balance ",
#         "preferred mode of mentorship": "Remote (Virtual)",
#         "your religion": "Christian",
#         "cultural influences": "Language usage",
#         "mentee demographics preference": "Close to me",
#         "latest educational qualification": "University",
#         "certifications": "Degree",
#         "current job title": "Volunteer",
#         "company": "GVRC; Nairobi Women's Hospital ",
#         "your area of expertise": "Counseling Psychology ",
#         "what are your career goals": "Self knowledge-The first important goal of mentoring is to help the individual in their own evaluation. A person needs to be enlightened, to know about himself, to identify his own strength, abilities, and possibilities. \nSelf-acceptance -refers to accepting one's own personality or image. There are many people who are unable to form a proper view of themselves and cannot take any decision.  In whatever form other people accept such people, they begin to accept them as their real nature. Their source of information about themselves is others point of view.\nSocial Cohesion -Being helpful in the social life of an individual is also considered to be another important goal of counseling. The emergence of various problems in our life is also due to not being able to make proper adjustments with society. In order to understand social life and behavior and to work in accordance with socially accepted behavior, one has to abandon the limits of one's own personal limitations. ",
#         "what skills would you like to mentor": "Positive attitude\nOpen to learning\nClear communication\nHard working\nGood time management ",
#         "what are your financial goals": "Building an emergency fund\nStarting a business\nFeeling financially secure",
#         "upload your resume if available": "https://drive.google.com/open?id=1p4QwgtWH2awjEG5EBDPGW6udAjtktFo0",
#         "linkedin url": NaN,
#         "x (formerly twitter url)": NaN,
#         "id": "./data/mentors.xlsx-43"
#     }
# ]
#
#     =================
#
#     Analyze the text above
#     Please identify whether not the above text contains any instances where a person's name is given
#     Please identify all email addresses
#     I need to find any exact dates that correspond to the day a person was born. They typically follow the format MM/DD/YYYY or DD/YY or other combinations.  They Must have a day number. Can you find them in the text?
#     Find any locations that could be a person's home address in this text. They must have a stret number or apartment number.
#
#     Your response should be a JSON record in this format:
#
#     {
#         "has_pii": <"yes" or "no">,
#         "fields": "<FIELD>, ..."
#         "values": "<VALUE>, ..."
#     }
#
#
# Error calling LLM
# content='```json\n{\n    "has_pii": "no",\n    "fields": "",\n    "values": ""\n}\n```'
# Error calling LLM
# content='```json\n{\n    "has_pii": "no",\n    "fields": "",\n    "values": ""\n}\n```'
# Error calling LLM
# content='```json\n{\n    "has_pii": "no",\n    "fields": "",\n    "values": ""\n}\n```'
# Error calling LLM
# content='```json\n{\n    "has_pii": "no",\n    "fields": "",\n    "values": ""\n}\n```'
# Error calling LLM
# content='```json\n{\n    "has_pii": "no",\n    "fields": "",\n    "values": ""\n}\n```'
# Error calling LLM. Max retries reached
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 matches = run_matching_batch(mentors, mentees, 'mentor', 'mentee', fields_context_prompt, fields_format_prompt, ai_check_prompt, \
#       2                    max_travel_distance_km, mentee_cap)
#
# Cell In[22], line 39, in run_matching_batch(data1, data2, rec1_name, rec2_name, fields_context_prompt, fields_format_prompt, ai_check_prompt, max_travel_distance_km, data2_cap, force)
#      37 # Please do not comment this out. :)
#      38 print("\n=====> Checking for PII  ...")
# ---> 39 check_pii(data1,chat)
#      40 check_pii(data2,chat)
#      42 print("\n=====> Calculating travel distance matrix ...")
#
# Cell In[21], line 75, in check_pii(data, chat)
#      71 print(prompt)
#      73 resp = call_llm("", prompt, chat)
# ---> 75 if resp['has_pii'] == 'yes':
#      76     print("PII detected!")
#      77     print(f"Fields: {resp['fields']}")
#
# TypeError: 'NoneType' object is not subscriptable
